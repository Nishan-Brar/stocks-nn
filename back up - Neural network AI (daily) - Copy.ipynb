# %% [markdown]
# # WHAT ABOUT THE SUBTRACTING A YEAR FROM ALL THE FEATURES DATES!!!!!!!!

# %% [markdown]
# # Import libraries

# %%
# ! pip uninstall -y tensorflow
# ! pip install tensorflow==2.10.*

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import decimal
import plotly.express as px
import plotly.graph_objects as go
from tqdm.notebook import tqdm
import os
from numba import jit
from multiprocessing import Pool
from outer_function_daily import outer_function
from rois import rois_func, portfolio_weights
from functools import partial
import numpy as np
import fredapi as fa
fred = fa.Fred(api_key="5b3325018adf679644bc330c41598801")

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization, Activation
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
from tensorflow_addons.metrics import RSquare
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from tensorflow.keras.optimizers import Adam

import bs4 as bs
import requests
import csv
import random
import datetime
import networkx as nx
import time
# Out:
# c:\Users\brarn\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\brarn\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.11.0 and strictly below 2.14.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
# Check if it detects GPU
tf.config.list_physical_devices('GPU') # need to use `! pip install tensorflow==2.10.*` to use gpu on windows 11 natively
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Import Data

# %% [markdown]
# ## Stock price data

# %%
# Import data
stocks_df = pd.read_csv("data/price.csv")

# Set date-time index
stocks_df['Date'] = pd.to_datetime(stocks_df["Date"], format='%Y/%m/%d')
stocks_df = stocks_df.set_index(stocks_df['Date'])
stocks_df = stocks_df.drop(columns = ["Date"])

# Drop all columns which only contain nan values
boolean = []
for stock in stocks_df.columns:
    boolean.append(not stocks_df[stock].isnull().all())
stocks_df = stocks_df.iloc[:, boolean]

stocks_df
# Out:
#                   AAPL       MSFT  GOOGL        GOOG        AMZN       BRK.B  \
# Date
# 1990-01-02         NaN  13.291009    NaN         NaN    0.264886         NaN
# 1990-01-03         NaN  13.488728    NaN         NaN    0.266664         NaN
# 1990-01-04         NaN  13.510702    NaN         NaN    0.267553         NaN
# 1990-01-05         NaN  13.378882    NaN         NaN    0.268442         NaN
# 1990-01-08         NaN  13.378882    NaN         NaN    0.270220         NaN
# ...                ...        ...    ...         ...         ...         ...
# 2022-12-20  147.929993  44.090000  12.53  139.380005  132.300003  160.580002
# 2022-12-21  150.089996  44.869999  13.03  142.289993  135.449997  162.210007
# 2022-12-22  149.009995  43.849998  12.56  142.080002  132.229996  163.270004
# 2022-12-23  149.229996  44.200001  12.71  143.279999  131.860001  163.100006
# 2022-12-27  149.550003  44.860001  12.53  145.020004  130.029999  162.990005
#
#                    UNH        JNJ         XOM          V  ...        UPST  \
# Date                                                      ...
# 1990-01-02         NaN        NaN    1.888242        NaN  ...         NaN
# 1990-01-03         NaN        NaN    1.895060        NaN  ...         NaN
# 1990-01-04         NaN        NaN    1.891651        NaN  ...         NaN
# 1990-01-05         NaN        NaN    1.871201        NaN  ...         NaN
# 1990-01-08         NaN        NaN    1.880794        NaN  ...         NaN
# ...                ...        ...         ...        ...  ...         ...
# 2022-12-20  167.380005  87.620003  106.489998  62.240002  ...  128.589996
# 2022-12-21  169.320007  87.070000  108.139999  63.360001  ...  128.779999
# 2022-12-22  169.270004  84.870003  108.029999  62.849998  ...  128.820007
# 2022-12-23  170.009995  85.250000  108.180000  63.380001  ...  128.899994
# 2022-12-27  169.000000  83.489998  108.570000  63.619999  ...  129.899994
#
#                   TAP          WE        CVNA       NVAX       EHAB  \
# Date
# 1990-01-02        NaN         NaN         NaN        NaN        NaN
# 1990-01-03        NaN         NaN         NaN        NaN        NaN
# 1990-01-04        NaN         NaN         NaN        NaN        NaN
# 1990-01-05        NaN         NaN         NaN        NaN        NaN
# 1990-01-08        NaN         NaN         NaN        NaN        NaN
# ...               ...         ...         ...        ...        ...
# 2022-12-20  33.619999  125.192581  247.149994  32.669998  28.730000
# 2022-12-21  33.950001  126.839455  250.839996  33.049999  29.309999
# 2022-12-22  33.459999  126.550003  247.509995  32.439999  28.950001
# 2022-12-23  33.130001  126.690002  248.220001  32.119999  28.799999
# 2022-12-27  32.500000  127.279999  251.000000  31.540001  28.549999
#
#                  OPEN       UWMC         MBC          FG
# Date
# 1990-01-02   1.963844        NaN         NaN         NaN
# 1990-01-03   1.998913        NaN         NaN         NaN
# 1990-01-04   1.998913        NaN         NaN         NaN
# 1990-01-05   1.998913        NaN         NaN         NaN
# 1990-01-08   1.998913        NaN         NaN         NaN
# ...               ...        ...         ...         ...
# 2022-12-20  46.130001  68.559998  113.540001  142.470001
# 2022-12-21  47.570000  69.930000  112.769997  144.919998
# 2022-12-22  48.279999  65.940002  109.360001  145.029999
# 2022-12-23  48.450001  65.889999  108.779999  145.759995
# 2022-12-27  48.840000  65.459999  107.570000  145.300003
#
# [8312 rows x 1005 columns]

# %%
# Convert to a numpy array for speedy opterations later on
stocks_np = stocks_df.to_numpy()
stocks_np
# Out:
# array([[         nan,  13.29100895,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,  13.48872757,          nan, ...,          nan,
#                  nan,          nan],
#        [         nan,  13.51070213,          nan, ...,          nan,
#                  nan,          nan],
#        ...,
#        [149.00999451,  43.84999847,  12.56000042, ...,  65.94000244,
#         109.36000061, 145.02999878],
#        [149.22999573,  44.20000076,  12.71000004, ...,  65.88999939,
#         108.77999878, 145.75999451],
#        [149.55000305,  44.86000061,  12.52999973, ...,  65.45999908,
#         107.56999969, 145.30000305]])

# %% [markdown]
# ## Categorical variable data

# %%
# Read data
cat_variables = pd.read_csv("data/categorical.csv")
cat_variables = cat_variables.set_index("Unnamed: 0")
cat_variables = cat_variables.rename_axis(None, axis = 0)
cat_variables = cat_variables.dropna(axis="columns")

# Drop stocks such that the remaining stocks are those in both cat_variables and stocks_df
intersection = list(set(stocks_df.columns) & set(cat_variables.columns))
cat_variables = cat_variables[intersection]
stocks_df = stocks_df[intersection]

cat_variables
# Out:
#                            MPWR           WY                    INTU  \
# sectors  Information Technology  Real Estate  Information Technology
#
#                  CUZ          UNH          RE         TREX        CNP     LNG  \
# sectors  Real Estate  Health Care  Financials  Industrials  Utilities  Energy
#
#                  JLL  ...                    TTWO               HSY  \
# sectors  Real Estate  ...  Communication Services  Consumer Staples
#
#                  UPS          CAH                    PYPL         ORI  \
# sectors  Industrials  Health Care  Information Technology  Financials
#
#                  RUN                     FND         AZTA         PCAR
# sectors  Industrials  Consumer Discretionary  Health Care  Industrials
#
# [1 rows x 1005 columns]

# %%
# Convert to a numpy array for speedy opterations later on
cat_variables_np = cat_variables.to_numpy()
cat_variables_np
# Out:
# array([['Information Technology', 'Real Estate',
#         'Information Technology', ..., 'Consumer Discretionary',
#         'Health Care', 'Industrials']], dtype=object)

# %%
# Get unique categories for each categorical variable
cats_df = pd.DataFrame()
for cat in cat_variables.index:
    uniques = list(cat_variables.loc[cat, :].unique())
    categories = np.sort(uniques)
    cats_df[cat] = categories

cats_df
# Out:
#                    sectors
# 0   Communication Services
# 1   Consumer Discretionary
# 2         Consumer Staples
# 3                   Energy
# 4               Financials
# 5              Health Care
# 6              Industrials
# 7   Information Technology
# 8   Information technology
# 9                Materials
# 10             Real Estate
# 11               Utilities

# %% [markdown]
# ## Numerical features data

# %%
# Read data
features_daily = pd.read_csv("data/features.csv")
features_daily['Date'] = pd.to_datetime(features_daily["Date"], format='%Y/%m/%d')
features_daily = features_daily.set_index("Date")
features_daily = features_daily.dropna()

# Make names smaller to use in file names
print(features_daily.columns)
features_daily.columns = ['BCI', 'CCI', 'CLI', '3m %', 'Broad $', 'Construction', 'Consumer prices', 'Manu $',
       'Indu production', 'Long %', 'MCI', 'Narrow $', 'Overnight %', 'Cars', 'producer $', 'Retail volume',
       'Total employment', 'Total manu']

features_daily
# Out:
# Index(['BCI', 'CCI', 'CLI', '3 month interbank rate', 'Broad money',
#        'Construction', 'Consumer prices', 'Manufacturing hourly earnings',
#        'Industrial production', 'Long-term interest rate',
#        'Manufacturing confidence indicator', 'Narrow money',
#        'Overnight interbank rate', 'Car registrations',
#        'Manufacturing producer prices', 'Retail trade volume',
#        'Total employment', 'Total manufacturing'],
#       dtype='object')
#                  BCI       CCI       CLI  3m %     Broad $  Construction  \
# Date
# 1990-01-01  98.82303  100.6509  99.79321  8.16   26.291189     40.385124
# 1990-01-02  98.82303  100.6509  99.79321  8.16   26.291189     40.385124
# 1990-01-03  98.82303  100.6509  99.79321  8.16   26.291189     40.385124
# 1990-01-04  98.82303  100.6509  99.79321  8.16   26.291189     40.385124
# 1990-01-05  98.82303  100.6509  99.79321  8.16   26.291189     40.385124
# ...              ...       ...       ...   ...         ...           ...
# 2022-12-23  98.91054   97.0624  98.88888  4.51  177.318578    164.796803
# 2022-12-24  98.91054   97.0624  98.88888  4.51  177.318578    164.796803
# 2022-12-25  98.91054   97.0624  98.88888  4.51  177.318578    164.796803
# 2022-12-26  98.91054   97.0624  98.88888  4.51  177.318578    164.796803
# 2022-12-27  98.91054   97.0624  98.88888  4.51  177.318578    164.796803
#
#             Consumer prices      Manu $  Indu production  Long %  MCI  \
# Date
# 1990-01-01        53.751419   52.855468        61.105826    8.21 -5.6
# 1990-01-02        53.751419   52.855468        61.105826    8.21 -5.6
# 1990-01-03        53.751419   52.855468        61.105826    8.21 -5.6
# 1990-01-04        53.751419   52.855468        61.105826    8.21 -5.6
# 1990-01-05        53.751419   52.855468        61.105826    8.21 -5.6
# ...                     ...         ...              ...     ...  ...
# 2022-12-23       125.221820  128.973371       100.598801    3.62 -3.2
# 2022-12-24       125.221820  128.973371       100.598801    3.62 -3.2
# 2022-12-25       125.221820  128.973371       100.598801    3.62 -3.2
# 2022-12-26       125.221820  128.973371       100.598801    3.62 -3.2
# 2022-12-27       125.221820  128.973371       100.598801    3.62 -3.2
#
#               Narrow $  Overnight %        Cars  producer $  Retail volume  \
# Date
# 1990-01-01   26.324891         8.23  138.407385   60.738345      67.509220
# 1990-01-02   26.324891         8.23  138.407385   60.738345      67.509220
# 1990-01-03   26.324891         8.23  138.407385   60.738345      67.509220
# 1990-01-04   26.324891         8.23  138.407385   60.738345      67.509220
# 1990-01-05   26.324891         8.23  138.407385   60.738345      67.509220
# ...                ...          ...         ...         ...            ...
# 2022-12-23  655.997485         4.10   37.603772  131.749933     118.300105
# 2022-12-24  655.997485         4.10   37.603772  131.749933     118.300105
# 2022-12-25  655.997485         4.10   37.603772  131.749933     118.300105
# 2022-12-26  655.997485         4.10   37.603772  131.749933     118.300105
# 2022-12-27  655.997485         4.10   37.603772  131.749933     118.300105
#
#             Total employment  Total manu
# Date
# 1990-01-01          119081.0   61.244983
# 1990-01-02          119081.0   61.244983
# 1990-01-03          119081.0   61.244983
# 1990-01-04          119081.0   61.244983
# 1990-01-05          119081.0   61.244983
# ...                      ...         ...
# 2022-12-23          159244.0   97.682796
# 2022-12-24          159244.0   97.682796
# 2022-12-25          159244.0   97.682796
# 2022-12-26          159244.0   97.682796
# 2022-12-27          159244.0   97.682796
#
# [12049 rows x 18 columns]

# %%
# Convert to a numpy array for speedy opterations later on
features_daily_np = features_daily.to_numpy()
features_daily_np
# Out:
# array([[9.88230300e+01, 1.00650900e+02, 9.97932100e+01, ...,
#         6.75092201e+01, 1.19081000e+05, 6.12449830e+01],
#        [9.88230300e+01, 1.00650900e+02, 9.97932100e+01, ...,
#         6.75092201e+01, 1.19081000e+05, 6.12449830e+01],
#        [9.88230300e+01, 1.00650900e+02, 9.97932100e+01, ...,
#         6.75092201e+01, 1.19081000e+05, 6.12449830e+01],
#        ...,
#        [9.89105400e+01, 9.70624000e+01, 9.88888800e+01, ...,
#         1.18300105e+02, 1.59244000e+05, 9.76827961e+01],
#        [9.89105400e+01, 9.70624000e+01, 9.88888800e+01, ...,
#         1.18300105e+02, 1.59244000e+05, 9.76827961e+01],
#        [9.89105400e+01, 9.70624000e+01, 9.88888800e+01, ...,
#         1.18300105e+02, 1.59244000e+05, 9.76827961e+01]])

# %% [markdown]
# # Hyperparameters

# %%
def get_feature_index(feature):
    """
    Returns the index in the numpy feature array using the features name.
    """
    return list(features_daily.columns).index(feature)

def get_cat_index(cat):
    """
    Returns the index in the numpy feature array using the features name.
    """
    return list(cat_variables.index).index(cat)

from itertools import chain, combinations

def powerset(iterable):
    s = list(iterable)
    return chain.from_iterable(combinations(s, r) for r in range(len(s)+1))

# %%
disable_progress_bars = False

# Constants
MAX_EPOCHS = 200
PATIENCE = 15
NUMBER_OF_RATES = 3

# Neural network hyperparameters to try
layers = [2, 3, 4]
neurons = [32, 64, 128]

# Techniques to try
techniques = ["base", "dropout layers", "batch regularisation", "dropout & batch"]

# Hyperparameters
years = [3, 4, 5]
lines = [16, 32,64]
batch_sizes = [2048]

# The categorical and numeric features included in the data are the ones at the SAME INDEX !!! ######################## what does this mean????????????????
cats_subsets = [["sectors"]]
features_subsets = [["Manu $", "Narrow $", "Cars", "Indu production"]]


if len(cats_subsets) != len(features_subsets):
    raise ValueError("The length of `cats_subsets` & `features_subsets` must be the same since the features included in the model "
                     "are those at the same indexes of these lists.")
all_cats = set()
for subset in cats_subsets:
    for var in subset:
        all_cats.add(var)
all_features = set()
for subset in features_subsets:
    for var in subset:
        all_features.add(var)

# Sort for consistency
all_cats = sorted(list(all_cats))
all_features = sorted(list(all_features))

all_cats_indexes = []
for var in all_cats:
    all_cats_indexes.append(get_cat_index(var))
all_features_indexes = []
for var in all_features:
    all_features_indexes.append(get_feature_index(var))


##### FOR `cats_subsets`
# Sort the names so that the name of the model files and graphs will always be the same regardless of the order of the names in the subset
# which allows the program to skip creating the model as it has already been created.
for i in range(len(cats_subsets)):
    cats_subsets[i].sort()

cats_indexes = []
for subset_names in cats_subsets:
    subset_indexes = []
    for feature in subset_names:
        subset_indexes.append(get_cat_index(feature))
    cats_indexes.append(subset_indexes)


##### FOR `features_subsets`
# Sort the names so that the name of the model files and graphs will always be the same regardless of the order of the names in the subset
# which allows the program to skip creating the model as it has already been created.
for i in range(len(features_subsets)):
    features_subsets[i].sort()

features_subsets_indexes = []
for subset_names in features_subsets:
    subset_indexes = []
    for feature in subset_names:
        subset_indexes.append(get_feature_index(feature))
    features_subsets_indexes.append(subset_indexes)

# %% [markdown]
# # Local host stuff

# %% [markdown]
# If cannot connect to local hosot, run both of the following commands in cmd using the code block below:
# * `taskkill /im tensorboard.exe /f`
# * `del /q %TMP%\.tensorboard-info\*`

# %%
# import os
# os.system('cmd /k "taskkill /im tensorboard.exe /f"')
# os.system('cmd /k "del /q %TMP%\.tensorboard-info\*"')
# 
# %load_ext tensorboard
# %tensorboard --logdir results --host localhost

# %% [markdown]
# # Training neural network on created data

# %% [markdown]
# * Very good explanation of [multiprocessing mapping methods](https://stackoverflow.com/questions/26520781/multiprocessing-pool-whats-the-difference-between-map-async-and-imap).
# * Good explanation of affect of [optimal chunksize](https://stackoverflow.com/questions/34988692/python-3-multiprocessing-optimal-chunk-size)

# %% [markdown]
# **I THINK THERE MAY STILL BE ROOM FOR IMPROVEMENT FOR IN MULTIPROCESSING BY VARYING CHUNKSIZE IN `imap` METHOD.**

# %%
def graph_already_completed(graph_path, layer, neuron):
    completed_graphs = os.listdir(graph_path)
    for graph_name in completed_graphs:
        if f"{layer}L-{neuron}N" in graph_name:
            return True
    return False

# %%
root_folder = "results (daily)"
overview_folder = "overview"
details_folder = "details"

# Create/load file to store results of each model
try:
    os.makedirs(f"{root_folder}/{overview_folder}")
except FileExistsError:
    pass


model_results_path = f"{root_folder}/{overview_folder}/model results.csv"
try:
    results = pd.read_csv(model_results_path)
except FileNotFoundError:
    # If the file does not exist then we create the file
    with open(model_results_path, "w") as f:
        f.write(",".join(["features","lines", "years", "layers", "neurons per layer", "total neurons", "batch size", "technique", "val_r_square"]) + "\n")
    results = pd.read_csv(model_results_path)

results
# Out:
# Empty DataFrame
# Columns: [features, lines, years, layers, neurons per layer, total neurons, batch size, technique, val_r_square]
# Index: []

# %%
# This also ensures that all the hyperparameters sets where no features (other than stock price) are considered always run first as they
# act as a base to compare to.
base_hyperparameter_combinations = []
for NUMBER_OF_LINES in lines:
    for NUMBER_OF_YEARS_TO_CONSIDER in years:
        tup = (NUMBER_OF_LINES, NUMBER_OF_YEARS_TO_CONSIDER)
        base_hyperparameter_combinations.append(tup)

base_hyperparameter_combinations
# Out:
# [(16, 3),
#  (16, 4),
#  (16, 5),
#  (32, 3),
#  (32, 4),
#  (32, 5),
#  (64, 3),
#  (64, 4),
#  (64, 5)]

# %%
# This also ensures that all the hyperparameters sets where no features (other than stock price) are considered always run first as they
# act as a base to compare to.
feature_combinations = []
for (subset_i, features_subset), (subset_j, cats_index) in zip(enumerate(features_subsets_indexes), enumerate(cats_indexes)):
    tup = ((subset_i, features_subset), (subset_j, cats_index))
    feature_combinations.append(tup)

feature_combinations
# Out:
# [((0, [13, 8, 7, 11]), (0, [0]))]

# %% [markdown]
# ## Dropping rows in results for models to redo

# %%
def remove_model_by_features(features_string, lines, years, layers, neurons_per_layer, results):
    index = results.loc[(results.features==features_string) &
                        (results.lines==lines) &
                        (results.years==years) &
                        (results.layers==layers) &
                        (results["neurons per layer"]==neurons_per_layer),:].index[0]
    results = results.drop(index, axis=0)
    return results

def remove_model_by_index(indexes, results):
    for i in indexes:
        results = results.drop(i, axis=0)
    return results

# %% [markdown]
# ### Remove by features

# %%
# # Table of models to redo (By features)
#
# table=[[]]
# for m in table:
#     features_string, lines, years, layers, neurons_per_layer = m
#     results = remove_model_by_features(features_string, lines, years, layers, neurons_per_layer, results)
# results.to_csv("model results.csv")

# %% [markdown]
# ### Remove by index

# %%
# # List of indexes to remove to redo the models
#
# list_of_index = []
# results = remove_model_by_index(list_of_index, results)
# results.to_csv("model results.csv")

# %% [markdown]
# ## Training the models

# %%
def plot(history, model, x_test, y_train, y_test, features_string, batch_size, i, R2, test_predictions):
    fig, ax = plt.subplots(1, 2, figsize=(13, 5), dpi=300)

    # PLot actual vs prediction scatter plot
    test_predictions = test_predictions.flatten()
    ax[0].scatter(y_test, test_predictions, alpha=0.01)
    ax[0].set_xlabel('True Values')
    ax[0].set_ylabel('Predictions')

    # Plot y=x line
    # ax[0].axline((0, 0), slope=1, c='green', linewidth=2)
    points = [0, max(max(y_test), max(test_predictions))]
    ax[0].plot(points, points, color="green", linewidth = 3)

    # Plot the average line
    # ax[0].axline((0, np.mean(y_train)), slope=0, c='red', linewidth=2, label='mean')
    x = [min(y_test), max(y_test)]
    y = [np.mean(y_train), np.mean(y_train)]
    ax[0].plot(x, y, color="red", linewidth = 3)
    ax[0].set_title("True values against predictions")

    ax[0].set_yscale('log')
    ax[0].set_xscale('log')

    # Plot training and testing r-squared
    ax[1].plot(history.history['r_square'], label='r_square')
    ax[1].plot(history.history['val_r_square'], label='val_r_square')
    ax[1].set_xlabel('Epoch')
    ax[1].set_ylabel('Error')
    ax[1].set_title('R-Squared')
    ax[1].set_ylim([0, 1])
    ax[1].set_yticks(np.arange(0, 1.05, 0.05))
    # xticks = np.arange(len(history.history['val_r_square'])) + 1
    # ax[1].set_xticks(xticks.astype(int))

    fig.suptitle(f"Test R2={round(R2,3)}, BS={batch_size}, result index={i}, {features_string}", fontsize="small")

    plt.legend()
    plt.grid(True)
    return fig

# %%
def models_remaining(layers, neurons, batch_sizes, techniques,feature_combinations, models_to_redo_by_index):
    for layer in layers:
        for neuron in neurons:
            for BATCH_SIZE in batch_sizes:
                for technique in techniques:
                    for (subset_i, features_subset), (subset_j, cats_index) in feature_combinations:
                        features_string = f"{cats_subsets[subset_j] + features_subsets[subset_i]}".replace("'","").replace(",","")
                        row = [features_string, NUMBER_OF_LINES, NUMBER_OF_YEARS_TO_CONSIDER, layer, neuron, layer*neuron, BATCH_SIZE, technique]

                        # The following determines if the current `row` index was designated to be trained further. The try-except clause takes into account the case
                        # where the `row` doesn't exist in `results` df.
                        try:
                            idx = (results[results.columns[:-1]] == row).index[0]
                        except IndexError:
                            boolean = False
                        else:
                            boolean = idx in models_to_redo_by_index
                        # If the model has been trained or needs to be trained more, we return True
                        if not (results[results.columns[:-1]] == row).all(1).any() or boolean:
                            return True
    return False

# %%
models_to_redo_by_index = []

# %%
p = Pool(os.cpu_count())
pbar = tqdm(total=len(base_hyperparameter_combinations)*len(feature_combinations)*len(layers)*len(neurons)*len(batch_sizes)*len(techniques), desc = "Completed models")
for NUMBER_OF_LINES, NUMBER_OF_YEARS_TO_CONSIDER in base_hyperparameter_combinations:
    if models_remaining(layers, neurons, batch_sizes, techniques,feature_combinations, models_to_redo_by_index):
        if NUMBER_OF_LINES <= NUMBER_OF_YEARS_TO_CONSIDER*365:
            first_index = NUMBER_OF_YEARS_TO_CONSIDER*365+1 # `+1` needed since slicing is end-exclusive
            range_iterations = range(first_index, len(stocks_np) - 365)

            iterations = tqdm(range_iterations,
                              desc=f"Working on Dataset: {NUMBER_OF_LINES} lines, {NUMBER_OF_YEARS_TO_CONSIDER} years",
                              disable=False)

            result_list = p.map(partial(outer_function,
                                        stocks_np = stocks_np,
                                        NUMBER_OF_YEARS_TO_CONSIDER = NUMBER_OF_YEARS_TO_CONSIDER,
                                        NUMBER_OF_LINES = NUMBER_OF_LINES,
                                        features_subset_indexes = all_features_indexes,
                                        features_np = features_daily_np,
                                        cats_np = cat_variables_np,
                                        cats_index = all_cats_indexes,
                                        cats_df = cats_df,
                                        dates = np.array(stocks_df.index),
                                        stocks = np.array(stocks_df.columns)
                                        ),
                                iterations)

            data = np.vstack([result[0] for result in result_list])
            # data = data.astype(np.float64) ## I don't think this is needed
            print(data)
            data_dates = np.hstack([result[1] for result in result_list])
            data_stocks = np.hstack([result[2] for result in result_list])

            cats_dict = dict()
            for k in all_cats_indexes:
                cats_dict[k] = np.hstack([result_list[i][3][k] for i in range(len(result_list))])

            features_dict = dict()
            for k in all_features_indexes:
                features_dict[k] = np.vstack([result_list[i][4][k] for i in range(len(result_list))])


            # Creating neural networks
            for layer in layers:
                for neuron in neurons:
                    for BATCH_SIZE in batch_sizes:
                        for technique in techniques:
                            for (subset_i, features_subset), (subset_j, cats_index) in feature_combinations:
                                data_name = f"{NUMBER_OF_LINES}Lines-{NUMBER_OF_YEARS_TO_CONSIDER}Years-{features_subsets[subset_i]}Features-{cats_subsets[subset_j]}Categorical".replace("'", "")
                                features_string = f"{cats_subsets[subset_j] + features_subsets[subset_i]}".replace("'","").replace(",","")
                                row = [features_string, NUMBER_OF_LINES, NUMBER_OF_YEARS_TO_CONSIDER, layer, neuron, layer*neuron, BATCH_SIZE, technique]
                                # The following determines if the current `row` index was designated to be trained further. The try-except clause takes into account the case
                                # where the `row` doesn't exist in `results` df.
                                try:
                                    idx = (results[results.columns[:-1]] == row).index[0]
                                except IndexError:
                                    boolean = False
                                else:
                                    boolean = idx in models_to_redo_by_index
                                    # If the model has been trained or needs to be trained more, we return True
                                if not (results[results.columns[:-1]] == row).all(1).any() or boolean:

                                    categorical_dummy_dfs_list = []
                                    for c in cats_index:
                                        categorical_dummy_dfs_list.append(pd.get_dummies(cats_dict[c]).iloc[:,:-1])


                                    # The `data` list must go last since the rest of the script expects the dependent variable to be the last column !!
                                    model_data = np.hstack(categorical_dummy_dfs_list + [features_dict[f] for f in features_subset] + [data])


                                    # Create data for model
                                    tuples = list(zip(data_dates, data_stocks))
                                    index = pd.MultiIndex.from_tuples(tuples, names=["dates", "stocks"])
                                    model_data = pd.DataFrame(model_data, index=index)

#############################################################################################################################################
                                    model_data_train = pd.concat([model_data.loc[:"2006-5-1",:], model_data.loc["2014-5-1":,:]], axis="rows").sample(frac=1,
                                                                                                                                                     random_state=1)
                                    model_data_test = model_data.loc["2006-5-1":"2014-5-1", :]
#############################################################################################################################################
                                    x_train = model_data_train.iloc[:,:-1]
                                    y_train = model_data_train.iloc[:,-1]

                                    x_test = model_data_test.iloc[:,:-1]
                                    y_test = model_data_test.iloc[:,-1]
#############################################################################################################################################
                                    test_dates = model_data_test.index
                                    
                                    # Create folders
                                    graphs_path = f'{root_folder}/{details_folder}/{technique}/models training & testing/{data_name}'
                                    try:
                                        os.makedirs(graphs_path)
                                    except FileExistsError:
                                        pass

                                    models_path = f'{root_folder}/{details_folder}/{technique}/models/{data_name}'
                                    try:
                                        os.makedirs(models_path)
                                    except FileExistsError:
                                        pass

                                    portfolio_creation_testing_path = f"{root_folder}/{details_folder}/{technique}/investment results/testing/{data_name}"
                                    try:
                                        os.makedirs(portfolio_creation_testing_path)
                                    except FileExistsError:
                                        pass

                                    portfolio_creation_training_path = f"{root_folder}/{details_folder}/{technique}/investment results/training/{data_name}"
                                    try:
                                        os.makedirs(portfolio_creation_training_path)
                                    except FileExistsError:
                                        pass

                                    model_name = f"{BATCH_SIZE}BS-{layer}Layers-{neuron}Neurons"

                                    print(f"\n"
                                          f"Working on model:\n"
                                          f"Data: {data_name}\n"
                                          f"Layers: {layer}\n"
                                          f"Neurons: {neuron}\n"
                                          f"Batch size = {BATCH_SIZE}\n"
                                          f"Technique = {technique}\n")

                                    # Normalize the data
                                    normalizer = preprocessing.Normalization(axis=-1)

                                    # The following determines if the current `row` index was designated to be trained further. The try-except clause takes into account the case
                                    # where the `row` doesn't exist in `results` df.
                                    try:
                                        idx = (results[results.columns[:-1]] == row).index[0]
                                    except IndexError:
                                        boolean = False
                                    else:
                                        boolean = idx in models_to_redo_by_index
                                        # If the model has been trained or needs to be trained more, we return True
                                    if not boolean:
                                        model = Sequential()
                                        model.add(normalizer)
                                        if technique == "dropout & batch":
                                            for _ in range(layer):
                                                model.add(Dense(neuron))
                                                model.add(BatchNormalization(axis=1))
                                                model.add(Activation("relu"))
                                                model.add(Dropout(0.5))
                                        else:
                                            for _ in range(layer):
                                                model.add(Dense(neuron))
                                                if technique == "batch regularisation":
                                                    model.add(BatchNormalization(axis=1))

                                                model.add(Activation("relu"))

                                                if technique == "dropout layers":
                                                    model.add(Dropout(0.5))
                                        model.add(Dense(1))
                                    else:
                                        model = tf.keras.models.load_model(f"{models_path}/{model_name}.h5")

                                    model.compile(loss='mean_absolute_error',
                                                  optimizer= Adam(learning_rate=0.00001),
                                                  metrics=[RSquare()])

                                    checkpoint_cb = ModelCheckpoint(f"{models_path}/{model_name}.h5",
                                                                    monitor='val_r_square',
                                                                    save_best_only=True,
                                                                    verbose=0,
                                                                    save_weights_only=False,
                                                                    mode = "max")
                                    early_stopping_cb = EarlyStopping(monitor = "val_r_square",
                                                                      patience = PATIENCE, # No. epochs with no improvement after which training is stopped.
                                                                      restore_best_weights=True,
                                                                      verbose = 0,
                                                                      min_delta = 0.01, # Increase of 0.01 per `PATIENCE` iterations required at least
                                                                      mode = "max")

                                    
                                    # tensorboard_callback = tf.keras.callbacks.TensorBoard(f"{root_folder}/{details_folder}/{technique}/logs/{data_name}/{model_name}")

                                    # reducelr_cb = ReduceLROnPlateau(monitor='val_r_square',
                                    #                                 factor=0.5,
                                    #                                 patience=REDUCE_LR_PATIENCE,
                                    #                                 verbose = 0,
                                    #                                 mode = "max")

                                    history = model.fit(
                                        x_train, y_train,
                                        validation_data = (x_test, y_test),
                                        verbose=1,
                                        epochs=MAX_EPOCHS,
                                        callbacks=[checkpoint_cb, early_stopping_cb], # , tensorboard_callback , reducelr_cb
                                        batch_size = BATCH_SIZE)

                                    model = tf.keras.models.load_model(f"{models_path}/{model_name}.h5")

                                    # Calculate r-squared
                                    test_predictions = model.predict(x_test, batch_size=BATCH_SIZE)
                                    R2_score = r2_score(y_test, test_predictions)
                                    plt.close("all")
                                    index = len(results)
                                    fig = plot(history, model, x_test, y_train, y_test, features_string, BATCH_SIZE, index, R2_score, test_predictions)
                                    plt.savefig(
                                        f'{graphs_path}/{model_name}.png',
                                        bbox_inches='tight',
                                        dpi = 300
                                    )

                                    # plt.show(fig)

                                    # Portfolio creation
                                    x_train_dates = [i[0] for i in x_train.index]
                                    x_train_stock = [i[1] for i in x_train.index]
                                    train_predictions = model.predict(x_train, batch_size=BATCH_SIZE)
                                    portfolio_data = np.array([x_train_dates,
                                                               x_train_stock,
                                                               x_train.iloc[:,-1],
                                                               y_train.values,
                                                               train_predictions[:,0]]
                                                              )
                                    portfolio_data = pd.DataFrame(portfolio_data.T,
                                                                  columns = ["date", "stock", "current price", "true 1 year", "predicted 1 year"])

                                    portfolio_data = portfolio_data.set_index("date")
                                    portfolio_data = portfolio_data.sort_values(by=["date", "predicted 1 year"], ascending=[True, False])

                                    rois_data = []
                                    pbar2 = tqdm(np.linspace(0,1,NUMBER_OF_RATES+1)[1:], desc="Trying different rates", total=NUMBER_OF_RATES)
                                    for rate in pbar2:
                                        rate = np.round(rate,3)
                                        tups = []
                                        for i in range(NUMBER_OF_RATES):
                                            tups.append((rate, portfolio_data))
                                        tups_tqdm = tqdm(tups, desc=f"Getting rois for rate: {rate}", total=len(tups))
                                        rois = p.map(rois_func, tups_tqdm)
                                        rois_data.append(np.vstack(rois))
                                    pbar2.close()

                                    rois_data = np.vstack(rois_data)
                                    rois_data = pd.DataFrame(rois_data, columns=["rate", "true roi", "expected roi", "num unique stocks"])
                                    # Drop nan rows as those represent times when all stocks were expected to go down
                                    rois_data = rois_data.dropna()

                                    best_rate = rois_data[["true roi", "rate"]].groupby(["rate"]).min().idxmax(axis="rows")[0]
                                    best_rate_min_roi = rois_data[["true roi", "rate"]].groupby(["rate"]).min().max(axis="rows")[0]

                                    plt.figure(figsize=(13, 5), dpi=300)

                                    # We are only going to invest when we expect a positive roi so only consider those.
                                    positive_rois_data = rois_data.loc[rois_data["expected roi"]>0,:]
                                    plt.axhline(0, color="green")
                                    plt.axhline(-50, color="yellow")
                                    plt.axhline(-100, color="red")
                                    sns.boxplot(data=positive_rois_data, x="rate", y="true roi") # , showfliers = False
                                    plt.title(f"best rate (lowest risk)={best_rate} with worst roi of: {round(best_rate_min_roi,2)}")
                                    plt.savefig(f"{portfolio_creation_training_path}/{model_name}.jpg")


                                    # Portfolio creation - interactive plot for testing data
                                    features_dates = [i[0] for i in model_data.iloc[:,:-1].index]
                                    features_stock = [i[1] for i in model_data.iloc[:,:-1].index]
                                    features_predictions = model.predict(model_data.iloc[:,:-1], batch_size=BATCH_SIZE)
                                    portfolio_data = np.array([features_dates,
                                                               features_stock,
                                                               model_data.iloc[:,:-1].iloc[:,-1],
                                                               model_data.iloc[:,-1].values,
                                                               features_predictions[:,0]]
                                                              )
                                    portfolio_data = pd.DataFrame(portfolio_data.T,
                                                                  columns = ["date", "stock", "current price", "true 1 year", "predicted 1 year"])

                                    portfolio_data = portfolio_data.sort_values(by=["date", "predicted 1 year"], ascending=[True, False])
                                    portfolio_data = portfolio_data.set_index("date")
                                    port_index = portfolio_data.index.unique()

                                    port_index_tqdm = tqdm(enumerate(port_index), desc="Getting portfolio rois", total=len(port_index))
                                    rois = np.zeros((len(port_index),2))
                                    extra_data = []
                                    for i, date in port_index_tqdm:
                                        if date in test_dates:
                                            dataset_string = "test"
                                        else:
                                            dataset_string = "train"

                                        # filter out relevant rows
                                        current_df = portfolio_data.loc[date,:]

                                        # Get array containing expected roi for each stock
                                        expected_roi_per_stock = ((current_df["predicted 1 year"].values - current_df["current price"].values)/current_df["current price"].values)*100
                                        current_df["expected roi"] = expected_roi_per_stock

                                        current_df = current_df.sort_values(["expected roi"], ascending=False)
                                        current_prices = current_df["current price"]
                                        current_stocks = current_df["stock"]
                                        expected_roi_per_stock = current_df["expected roi"]

                                        weights, num_stocks = portfolio_weights(best_rate, expected_roi_per_stock)

                                        stocks_to_show = 10
                                        weights_string = " ".join(list([str(round(num, 2)) for num in list(weights)[:stocks_to_show]]))
                                        stocks_string = " ".join(list(current_stocks)[:stocks_to_show])
                                        current_prices_string = " ".join(list([str(round(num, 2)) for num in list(current_prices)[:stocks_to_show]]))
                                        predicted_prices_string = " ".join(list([str(round(num, 2)) for num in list(current_df["predicted 1 year"])])[:stocks_to_show])
                                        expected_roi_string = " ".join(list([str(round(num, 2)) for num in list(expected_roi_per_stock)[:stocks_to_show]]))
                                        true_price_string = " ".join(list([str(round(num, 2)) for num in list(current_df["true 1 year"])[:stocks_to_show]]))

                                        current_portfolio_wealth = sum([weights[w] * decimal.Decimal(current_df["current price"][w]) for w in range(len(weights))])
                                        current_portfolio_wealth = float(current_portfolio_wealth)


                                        future_true_wealth = sum([weights[w] * decimal.Decimal(current_df.loc[:, "true 1 year"][w]) for w in range(len(weights))])
                                        future_true_wealth = float(future_true_wealth)


                                        future_predicted_wealth = sum([weights[w] * decimal.Decimal(current_df.loc[:, "predicted 1 year"][w]) for w in range(len(weights))])
                                        future_predicted_wealth = float(future_predicted_wealth)

                                        if not current_portfolio_wealth == 0:
                                            true_roi = ((future_true_wealth-current_portfolio_wealth)/current_portfolio_wealth)*100
                                            expected_roi = ((future_predicted_wealth-current_portfolio_wealth)/current_portfolio_wealth)*100
                                        else:
                                            # The nans represent days when no stocks were expected to increase in price after 1 year
                                            true_roi = np.nan
                                            expected_roi = np.nan

                                        rois[i, :] = np.array([true_roi, expected_roi])
                                        # Append data
                                        extra_data.append([stocks_string, current_prices_string, true_price_string, predicted_prices_string, expected_roi_string, num_stocks, weights_string, dataset_string])

                                    rois_data = pd.DataFrame(rois, columns = ["true roi", "expected roi"], index=port_index)
                                    extra_data = pd.DataFrame(extra_data,
                                                              columns = ["stocks", "current stock prices", "1Y true prices", "1Y predicted prices", "stocks expected roi", "num unique stocks", "weights", "dataset"],
                                                              index=port_index)
                                    extra_data["date"] = [str(date.date()) for date in extra_data.index]

                                    rois_data = pd.concat([rois_data, extra_data], axis="columns", ignore_index=False)
                                    # Drop nan rows as those represent times when all stocks were expected to go down
                                    rois_data = rois_data.dropna()

                                    print("Creating interactive scatterplot")
                                    r_squared_train = r2_score(rois_data.loc[rois_data.dataset == "train", "true roi"], rois_data.loc[rois_data.dataset == "train", "expected roi"])
                                    r_squared_test = r2_score(rois_data.loc[rois_data.dataset == "test", "true roi"], rois_data.loc[rois_data.dataset == "test", "expected roi"])
                                    fig = px.scatter(rois_data,
                                                     x="true roi", y="expected roi",
                                                     title = f"Train r2 = {round(r_squared_train,3)}, Test r2 = {round(r_squared_test,3)}",
                                                     hover_data=extra_data.columns,
                                                     marginal_x="box", marginal_y="box",
                                                     color = "dataset"
                                                     )
                                    # Add a line trace with y=x to the figure
                                    fig.add_trace(go.Scatter(x=[rois_data["true roi"].min(), rois_data["true roi"].max()],
                                                             y=[rois_data["true roi"].min(), rois_data["true roi"].max()],
                                                             mode='lines',
                                                             name='y=x'))

                                    print("Saving interactive scatterplot")
                                    fig.write_html(f"{portfolio_creation_testing_path}/{model_name}.html")
                                    print("Saved interactive scatterplot")


                                    # Add result to `results` dataframe and to "model results.csv"
                                    total_neurons = layer * neuron
                                    result_row = [features_string, NUMBER_OF_LINES, NUMBER_OF_YEARS_TO_CONSIDER, layer, neuron, total_neurons, BATCH_SIZE, technique, R2_score]
                                    results = results.append({"features":features_string,
                                                              "lines":NUMBER_OF_LINES,
                                                              "years":NUMBER_OF_YEARS_TO_CONSIDER,
                                                              "layers":layer,
                                                              "neurons per layer":neuron,
                                                              "total neurons":total_neurons,
                                                              "batch size":BATCH_SIZE,
                                                              "technique":technique,
                                                              "val_r_square":R2_score}, ignore_index=True)


                                    with open(f"{root_folder}/{overview_folder}/model results.csv", "a") as f:
                                        writer = csv.writer(f)
                                        writer.writerow(result_row)
                                else:
                                    print(f"\n"
                                          f"ALREADY COMPLETED model:\n"
                                          f"Data: {data_name}\n"
                                          f"Layers: {layer}\n"
                                          f"Neurons: {neuron}\n"
                                          f"Batch size = {BATCH_SIZE}\n"
                                          f"Technique = {technique}\n")
                                pbar.update(1)

            # Now create the interactive plots
            for col in results.columns[:-1]:
                fig = px.scatter(results, x=col, y="val_r_square",
                                 color = "features",
                                 size = list(results["total neurons"]),
                                 hover_data=results.columns[:-1],
                                 title = f"R2 score against {col}"
                                 )
                fig.update_yaxes(range = [0, 1.05])
                fig.write_html(f"{root_folder}/{overview_folder}/R2 score against {col}.html")

        else:
            raise ValueError("Condition not met: NUMBER_OF_LINES <= NUMBER_OF_YEARS_TO_CONSIDER*365")
    else:
        pbar.update(len(feature_combinations)*len(layers)*len(neurons)*len(batch_sizes)*len(techniques))

p.close()
p.join()
pbar.close()
# Out:
# Completed models:   0%|          | 0/324 [00:00<?, ?it/s]
# Working on Dataset: 16 lines, 3 years:   0%|          | 0/6851 [00:00<?, ?it/s]
# [[-1.20077523e-02  1.18083463e-02 -2.80185549e-02 ... -3.27100657e-02
#    1.42519188e+01  2.20107765e+01]
#  [ 7.24663501e-04  4.10631739e-04 -1.71848093e-03 ... -5.87561614e-04
#    2.30860427e-01  2.63182461e-01]
#  [-9.32663268e-04  8.98324470e-03 -3.55583253e-04 ... -2.82317040e-03
#    3.46025252e+00  5.00519133e+00]
#  ...
#  [ 2.05124583e-01 -1.67932039e-01  1.67128271e-02 ... -3.76569270e-01
#    1.06279999e+02  3.21199989e+01]
#  [-2.51722271e-02  4.13431579e-03  7.15533175e-02 ... -6.15805373e-02
#    5.16699982e+01  4.84500008e+01]
#  [ 1.72831766e-01  1.86029361e-02  1.64174320e-01 ...  4.88611922e-01
#    1.99428116e+02  1.45759995e+02]]
#
# Working on model:
# Data: 16Lines-3Years-[Cars, Indu production, Manu $, Narrow $]Features-[sectors]Categorical
# Layers: 2
# Neurons: 32
# Batch size = 2048
# Technique = base
#
# WARNING:tensorflow:From c:\Users\brarn\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/200
# WARNING:tensorflow:From c:\Users\brarn\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1398/1398 [==============================] - 4s 2ms/step - loss: 51.8945 - r_square: 0.1140 - val_loss: 23.9456 - val_r_square: 0.3262
# Epoch 2/200
#   79/1398 [>.............................] - ETA: 1s - loss: 43.2963 - r_square: 0.3261
# c:\Users\brarn\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1398/1398 [==============================] - 2s 2ms/step - loss: 37.3992 - r_square: 0.4770 - val_loss: 19.3154 - val_r_square: 0.6088
# Epoch 3/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 26.8926 - r_square: 0.7279 - val_loss: 15.3207 - val_r_square: 0.7926
# Epoch 4/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 19.4668 - r_square: 0.8660 - val_loss: 12.4831 - val_r_square: 0.8743
# Epoch 5/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 17.0239 - r_square: 0.9063 - val_loss: 11.5443 - val_r_square: 0.8869
# Epoch 6/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.7176 - r_square: 0.9103 - val_loss: 11.4400 - val_r_square: 0.8878
# Epoch 7/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.6651 - r_square: 0.9106 - val_loss: 11.4016 - val_r_square: 0.8881
# Epoch 8/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.6298 - r_square: 0.9108 - val_loss: 11.3829 - val_r_square: 0.8880
# Epoch 9/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.6078 - r_square: 0.9109 - val_loss: 11.3810 - val_r_square: 0.8880
# Epoch 10/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.5907 - r_square: 0.9110 - val_loss: 11.3817 - val_r_square: 0.8880
# Epoch 11/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.5760 - r_square: 0.9111 - val_loss: 11.3716 - val_r_square: 0.8881
# Epoch 12/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.5634 - r_square: 0.9112 - val_loss: 11.3761 - val_r_square: 0.8879
# Epoch 13/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.5511 - r_square: 0.9112 - val_loss: 11.3665 - val_r_square: 0.8880
# Epoch 14/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.5393 - r_square: 0.9113 - val_loss: 11.3635 - val_r_square: 0.8879
# Epoch 15/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.5272 - r_square: 0.9114 - val_loss: 11.3535 - val_r_square: 0.8878
# Epoch 16/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.5159 - r_square: 0.9115 - val_loss: 11.3479 - val_r_square: 0.8879
# Epoch 17/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.5043 - r_square: 0.9116 - val_loss: 11.3354 - val_r_square: 0.8880
# Epoch 18/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.4928 - r_square: 0.9117 - val_loss: 11.3318 - val_r_square: 0.8879
# Epoch 19/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.4809 - r_square: 0.9118 - val_loss: 11.3262 - val_r_square: 0.8881
# Epoch 20/200
# 1398/1398 [==============================] - 2s 2ms/step - loss: 16.4692 - r_square: 0.9120 - val_loss: 11.3312 - val_r_square: 0.8879
# 646/646 [==============================] - 1s 791us/step
# 1398/1398 [==============================] - 1s 838us/step
# Trying different rates:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.333:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.667:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 1.0:   0%|          | 0/3 [00:00<?, ?it/s]
# 2044/2044 [==============================] - 2s 858us/step
# Getting portfolio rois:   0%|          | 0/6851 [00:00<?, ?it/s]
# Creating interactive scatterplot
# Saving interactive scatterplot
# Saved interactive scatterplot
# C:\Users\brarn\AppData\Local\Temp\ipykernel_8072\1656905027.py:362: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Working on model:
# Data: 16Lines-3Years-[Cars, Indu production, Manu $, Narrow $]Features-[sectors]Categorical
# Layers: 2
# Neurons: 32
# Batch size = 2048
# Technique = dropout layers
#
# Epoch 1/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 63.7735 - r_square: -0.1274 - val_loss: 25.7711 - val_r_square: 0.1065
# Epoch 2/200
#   69/1398 [>.............................] - ETA: 2s - loss: 58.2582 - r_square: 0.0323
# c:\Users\brarn\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 1398/1398 [==============================] - 4s 3ms/step - loss: 54.9711 - r_square: 0.1373 - val_loss: 22.9931 - val_r_square: 0.3473
# Epoch 3/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 47.6018 - r_square: 0.3569 - val_loss: 20.8587 - val_r_square: 0.5472
# Epoch 4/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 41.1550 - r_square: 0.5209 - val_loss: 19.5581 - val_r_square: 0.6925
# Epoch 5/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 36.0401 - r_square: 0.6324 - val_loss: 19.1562 - val_r_square: 0.7880
# Epoch 6/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 32.8413 - r_square: 0.6755 - val_loss: 18.6365 - val_r_square: 0.8378
# Epoch 7/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 30.9098 - r_square: 0.6977 - val_loss: 17.4945 - val_r_square: 0.8584
# Epoch 8/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 29.6604 - r_square: 0.7096 - val_loss: 16.0698 - val_r_square: 0.8681
# Epoch 9/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 28.8135 - r_square: 0.7158 - val_loss: 14.9265 - val_r_square: 0.8727
# Epoch 10/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 28.1924 - r_square: 0.7208 - val_loss: 14.2402 - val_r_square: 0.8746
# Epoch 11/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 27.5925 - r_square: 0.7336 - val_loss: 13.8559 - val_r_square: 0.8759
# Epoch 12/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 27.1929 - r_square: 0.7355 - val_loss: 13.5826 - val_r_square: 0.8758
# Epoch 13/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 26.8232 - r_square: 0.7464 - val_loss: 13.4267 - val_r_square: 0.8762
# Epoch 14/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 26.5059 - r_square: 0.7547 - val_loss: 13.3249 - val_r_square: 0.8762
# Epoch 15/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 26.2655 - r_square: 0.7560 - val_loss: 13.1683 - val_r_square: 0.8768
# Epoch 16/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 25.9995 - r_square: 0.7655 - val_loss: 13.1497 - val_r_square: 0.8768
# Epoch 17/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 25.7139 - r_square: 0.7735 - val_loss: 12.9959 - val_r_square: 0.8775
# Epoch 18/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 25.5922 - r_square: 0.7698 - val_loss: 12.9792 - val_r_square: 0.8768
# Epoch 19/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 25.4483 - r_square: 0.7728 - val_loss: 12.8992 - val_r_square: 0.8762
# Epoch 20/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 25.2956 - r_square: 0.7744 - val_loss: 12.8097 - val_r_square: 0.8767
# Epoch 21/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 25.1522 - r_square: 0.7809 - val_loss: 12.7004 - val_r_square: 0.8762
# Epoch 22/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 25.0533 - r_square: 0.7791 - val_loss: 12.7085 - val_r_square: 0.8754
# Epoch 23/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 24.9625 - r_square: 0.7812 - val_loss: 12.6428 - val_r_square: 0.8754
# Epoch 24/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 24.8381 - r_square: 0.7873 - val_loss: 12.6572 - val_r_square: 0.8752
# 646/646 [==============================] - 1s 788us/step
# 1398/1398 [==============================] - 1s 835us/step
# Trying different rates:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.333:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.667:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 1.0:   0%|          | 0/3 [00:00<?, ?it/s]
# 2044/2044 [==============================] - 2s 841us/step
# Getting portfolio rois:   0%|          | 0/6851 [00:00<?, ?it/s]
# Creating interactive scatterplot
# Saving interactive scatterplot
# Saved interactive scatterplot
# C:\Users\brarn\AppData\Local\Temp\ipykernel_8072\1656905027.py:362: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Working on model:
# Data: 16Lines-3Years-[Cars, Indu production, Manu $, Narrow $]Features-[sectors]Categorical
# Layers: 2
# Neurons: 32
# Batch size = 2048
# Technique = batch regularisation
#
# Epoch 1/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 65.9174 - r_square: -0.1582 - val_loss: 42.9433 - val_r_square: -0.1792
# Epoch 2/200
#   61/1398 [>.............................] - ETA: 3s - loss: 65.1426 - r_square: -0.1611
# c:\Users\brarn\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 1398/1398 [==============================] - 3s 2ms/step - loss: 65.2470 - r_square: -0.1607 - val_loss: 42.7050 - val_r_square: -0.1798
# Epoch 3/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 64.7783 - r_square: -0.1598 - val_loss: 42.4855 - val_r_square: -0.1786
# Epoch 4/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 64.4038 - r_square: -0.1580 - val_loss: 42.2323 - val_r_square: -0.1753
# Epoch 5/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 64.0530 - r_square: -0.1555 - val_loss: 41.9812 - val_r_square: -0.1723
# Epoch 6/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 63.7044 - r_square: -0.1525 - val_loss: 41.6729 - val_r_square: -0.1680
# Epoch 7/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 63.3479 - r_square: -0.1491 - val_loss: 41.3258 - val_r_square: -0.1633
# Epoch 8/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 62.9706 - r_square: -0.1458 - val_loss: 40.9988 - val_r_square: -0.1586
# Epoch 9/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 62.6088 - r_square: -0.1421 - val_loss: 40.8196 - val_r_square: -0.1549
# Epoch 10/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 62.2640 - r_square: -0.1388 - val_loss: 40.5321 - val_r_square: -0.1515
# Epoch 11/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 61.9268 - r_square: -0.1356 - val_loss: 40.2050 - val_r_square: -0.1470
# Epoch 12/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 61.5959 - r_square: -0.1324 - val_loss: 39.8694 - val_r_square: -0.1428
# Epoch 13/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 61.2545 - r_square: -0.1290 - val_loss: 39.5699 - val_r_square: -0.1388
# Epoch 14/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 60.8966 - r_square: -0.1258 - val_loss: 39.2724 - val_r_square: -0.1356
# Epoch 15/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 60.5251 - r_square: -0.1227 - val_loss: 38.9448 - val_r_square: -0.1318
# Epoch 16/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 60.1519 - r_square: -0.1198 - val_loss: 38.6212 - val_r_square: -0.1276
# Epoch 17/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 59.7773 - r_square: -0.1167 - val_loss: 38.2899 - val_r_square: -0.1236
# Epoch 18/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 59.3984 - r_square: -0.1134 - val_loss: 37.9481 - val_r_square: -0.1188
# Epoch 19/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 59.0146 - r_square: -0.1099 - val_loss: 37.6387 - val_r_square: -0.1148
# Epoch 20/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 58.6223 - r_square: -0.1066 - val_loss: 37.2768 - val_r_square: -0.1106
# Epoch 21/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 58.2218 - r_square: -0.1033 - val_loss: 36.9162 - val_r_square: -0.1063
# Epoch 22/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 57.8148 - r_square: -0.1000 - val_loss: 36.5252 - val_r_square: -0.1014
# Epoch 23/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 57.4005 - r_square: -0.0961 - val_loss: 36.2213 - val_r_square: -0.0962
# Epoch 24/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 56.9799 - r_square: -0.0923 - val_loss: 35.8184 - val_r_square: -0.0912
# Epoch 25/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 56.5541 - r_square: -0.0890 - val_loss: 35.4594 - val_r_square: -0.0867
# Epoch 26/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 56.1216 - r_square: -0.0856 - val_loss: 35.0969 - val_r_square: -0.0822
# Epoch 27/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 55.6819 - r_square: -0.0822 - val_loss: 34.7091 - val_r_square: -0.0774
# Epoch 28/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 55.2345 - r_square: -0.0786 - val_loss: 34.2502 - val_r_square: -0.0720
# Epoch 29/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 54.7717 - r_square: -0.0750 - val_loss: 33.7848 - val_r_square: -0.0669
# Epoch 30/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 54.2986 - r_square: -0.0716 - val_loss: 33.3514 - val_r_square: -0.0614
# Epoch 31/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 53.8113 - r_square: -0.0681 - val_loss: 32.8154 - val_r_square: -0.0549
# Epoch 32/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 53.2899 - r_square: -0.0646 - val_loss: 31.8056 - val_r_square: -0.0471
# Epoch 33/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 52.7272 - r_square: -0.0616 - val_loss: 30.6843 - val_r_square: -0.0428
# Epoch 34/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 52.1720 - r_square: -0.0581 - val_loss: 29.9890 - val_r_square: -0.0378
# Epoch 35/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 51.6255 - r_square: -0.0542 - val_loss: 29.4012 - val_r_square: -0.0318
# Epoch 36/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 51.0753 - r_square: -0.0503 - val_loss: 28.8726 - val_r_square: -0.0261
# Epoch 37/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 50.5259 - r_square: -0.0466 - val_loss: 28.3633 - val_r_square: -0.0210
# Epoch 38/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 49.9723 - r_square: -0.0428 - val_loss: 27.7511 - val_r_square: -0.0157
# Epoch 39/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 49.4082 - r_square: -0.0389 - val_loss: 27.0867 - val_r_square: -0.0099
# Epoch 40/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 48.8371 - r_square: -0.0349 - val_loss: 26.4947 - val_r_square: -0.0042
# Epoch 41/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 48.2624 - r_square: -0.0311 - val_loss: 25.9509 - val_r_square: 6.2537e-04
# Epoch 42/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 47.6819 - r_square: -0.0268 - val_loss: 25.5702 - val_r_square: 0.0063
# Epoch 43/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 47.0976 - r_square: -0.0229 - val_loss: 25.0010 - val_r_square: 0.0109
# Epoch 44/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 46.5133 - r_square: -0.0182 - val_loss: 24.6022 - val_r_square: 0.0166
# Epoch 45/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 45.9246 - r_square: -0.0130 - val_loss: 24.1329 - val_r_square: 0.0231
# Epoch 46/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 45.3422 - r_square: -0.0078 - val_loss: 23.7242 - val_r_square: 0.0295
# Epoch 47/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 44.7528 - r_square: -0.0020 - val_loss: 23.2705 - val_r_square: 0.0377
# Epoch 48/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 44.1632 - r_square: 0.0045 - val_loss: 22.7820 - val_r_square: 0.0480
# Epoch 49/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 43.5693 - r_square: 0.0116 - val_loss: 22.5263 - val_r_square: 0.0581
# Epoch 50/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 42.9639 - r_square: 0.0197 - val_loss: 22.1963 - val_r_square: 0.0663
# Epoch 51/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 42.3638 - r_square: 0.0288 - val_loss: 21.8687 - val_r_square: 0.0786
# Epoch 52/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 41.7654 - r_square: 0.0402 - val_loss: 21.4613 - val_r_square: 0.0911
# Epoch 53/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 41.1588 - r_square: 0.0513 - val_loss: 21.4265 - val_r_square: 0.1017
# Epoch 54/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 40.5188 - r_square: 0.0641 - val_loss: 21.2643 - val_r_square: 0.1123
# Epoch 55/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 39.8206 - r_square: 0.0758 - val_loss: 21.1720 - val_r_square: 0.1168
# Epoch 56/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 39.1164 - r_square: 0.0850 - val_loss: 20.9760 - val_r_square: 0.1214
# Epoch 57/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 38.4145 - r_square: 0.0934 - val_loss: 20.7572 - val_r_square: 0.1240
# Epoch 58/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 37.7018 - r_square: 0.1012 - val_loss: 21.1104 - val_r_square: 0.1243
# Epoch 59/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 36.9849 - r_square: 0.1080 - val_loss: 20.8929 - val_r_square: 0.1268
# Epoch 60/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 36.2703 - r_square: 0.1153 - val_loss: 20.8975 - val_r_square: 0.1311
# Epoch 61/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 35.5627 - r_square: 0.1233 - val_loss: 20.7641 - val_r_square: 0.1366
# Epoch 62/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 34.8732 - r_square: 0.1313 - val_loss: 20.8204 - val_r_square: 0.1413
# Epoch 63/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 34.2045 - r_square: 0.1402 - val_loss: 20.5513 - val_r_square: 0.1487
# Epoch 64/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 33.5414 - r_square: 0.1495 - val_loss: 20.2876 - val_r_square: 0.1572
# Epoch 65/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 32.9120 - r_square: 0.1605 - val_loss: 19.9569 - val_r_square: 0.1655
# Epoch 66/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 32.2800 - r_square: 0.1710 - val_loss: 19.6151 - val_r_square: 0.1757
# Epoch 67/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 31.6652 - r_square: 0.1821 - val_loss: 19.3987 - val_r_square: 0.1832
# Epoch 68/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 31.0721 - r_square: 0.1936 - val_loss: 19.0144 - val_r_square: 0.1942
# Epoch 69/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 30.5073 - r_square: 0.2053 - val_loss: 18.6775 - val_r_square: 0.2084
# Epoch 70/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 29.9469 - r_square: 0.2189 - val_loss: 18.6170 - val_r_square: 0.2169
# Epoch 71/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 29.4135 - r_square: 0.2321 - val_loss: 18.4345 - val_r_square: 0.2297
# Epoch 72/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 28.9032 - r_square: 0.2461 - val_loss: 18.0361 - val_r_square: 0.2440
# Epoch 73/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 28.3920 - r_square: 0.2605 - val_loss: 17.9020 - val_r_square: 0.2559
# Epoch 74/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 27.9075 - r_square: 0.2753 - val_loss: 17.6670 - val_r_square: 0.2710
# Epoch 75/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 27.4363 - r_square: 0.2904 - val_loss: 17.5526 - val_r_square: 0.2880
# Epoch 76/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 26.9818 - r_square: 0.3071 - val_loss: 17.3604 - val_r_square: 0.2965
# Epoch 77/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 26.5463 - r_square: 0.3224 - val_loss: 17.2550 - val_r_square: 0.3139
# Epoch 78/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 26.1360 - r_square: 0.3388 - val_loss: 17.1990 - val_r_square: 0.3267
# Epoch 79/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 25.7124 - r_square: 0.3546 - val_loss: 16.9482 - val_r_square: 0.3444
# Epoch 80/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 25.3234 - r_square: 0.3707 - val_loss: 16.8393 - val_r_square: 0.3651
# Epoch 81/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 24.9527 - r_square: 0.3873 - val_loss: 16.6017 - val_r_square: 0.3738
# Epoch 82/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 24.5906 - r_square: 0.4030 - val_loss: 16.6206 - val_r_square: 0.3959
# Epoch 83/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 24.2470 - r_square: 0.4204 - val_loss: 16.5133 - val_r_square: 0.4015
# Epoch 84/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 23.9210 - r_square: 0.4353 - val_loss: 16.2672 - val_r_square: 0.4239
# Epoch 85/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 23.6027 - r_square: 0.4529 - val_loss: 16.2331 - val_r_square: 0.4321
# Epoch 86/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 23.2981 - r_square: 0.4682 - val_loss: 16.1993 - val_r_square: 0.4508
# Epoch 87/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 23.0061 - r_square: 0.4837 - val_loss: 15.8821 - val_r_square: 0.4677
# Epoch 88/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 22.7164 - r_square: 0.5006 - val_loss: 15.9930 - val_r_square: 0.4806
# Epoch 89/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 22.4433 - r_square: 0.5159 - val_loss: 15.7884 - val_r_square: 0.4941
# Epoch 90/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 22.1716 - r_square: 0.5316 - val_loss: 15.5814 - val_r_square: 0.5130
# Epoch 91/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 21.9377 - r_square: 0.5455 - val_loss: 15.5060 - val_r_square: 0.5331
# Epoch 92/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 21.6950 - r_square: 0.5610 - val_loss: 15.3387 - val_r_square: 0.5406
# Epoch 93/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 21.4629 - r_square: 0.5753 - val_loss: 15.3556 - val_r_square: 0.5511
# Epoch 94/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 21.2395 - r_square: 0.5900 - val_loss: 15.2848 - val_r_square: 0.5699
# Epoch 95/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 21.0490 - r_square: 0.6019 - val_loss: 15.0774 - val_r_square: 0.5823
# Epoch 96/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 20.8497 - r_square: 0.6150 - val_loss: 15.0025 - val_r_square: 0.5965
# Epoch 97/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 20.6729 - r_square: 0.6278 - val_loss: 14.9064 - val_r_square: 0.6026
# Epoch 98/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 20.4975 - r_square: 0.6381 - val_loss: 14.7564 - val_r_square: 0.6248
# Epoch 99/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 20.3398 - r_square: 0.6502 - val_loss: 14.7081 - val_r_square: 0.6306
# Epoch 100/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 20.1808 - r_square: 0.6620 - val_loss: 14.5412 - val_r_square: 0.6443
# Epoch 101/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 20.0268 - r_square: 0.6721 - val_loss: 14.5485 - val_r_square: 0.6539
# Epoch 102/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 19.8991 - r_square: 0.6807 - val_loss: 14.3650 - val_r_square: 0.6615
# Epoch 103/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 19.7614 - r_square: 0.6916 - val_loss: 14.4307 - val_r_square: 0.6670
# Epoch 104/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 19.6489 - r_square: 0.6996 - val_loss: 14.3044 - val_r_square: 0.6800
# Epoch 105/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 19.5247 - r_square: 0.7076 - val_loss: 14.2977 - val_r_square: 0.6872
# Epoch 106/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 19.4190 - r_square: 0.7160 - val_loss: 14.2341 - val_r_square: 0.7007
# Epoch 107/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 19.3139 - r_square: 0.7233 - val_loss: 14.2533 - val_r_square: 0.6997
# Epoch 108/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 19.2063 - r_square: 0.7309 - val_loss: 14.0495 - val_r_square: 0.7184
# Epoch 109/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 19.1097 - r_square: 0.7372 - val_loss: 14.0790 - val_r_square: 0.7208
# Epoch 110/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 19.0271 - r_square: 0.7431 - val_loss: 14.1245 - val_r_square: 0.7149
# Epoch 111/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.9425 - r_square: 0.7499 - val_loss: 14.0884 - val_r_square: 0.7278
# Epoch 112/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.8864 - r_square: 0.7533 - val_loss: 14.0645 - val_r_square: 0.7367
# Epoch 113/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.7920 - r_square: 0.7602 - val_loss: 14.0014 - val_r_square: 0.7513
# Epoch 114/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.7016 - r_square: 0.7660 - val_loss: 14.1257 - val_r_square: 0.7358
# Epoch 115/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.6439 - r_square: 0.7705 - val_loss: 14.0061 - val_r_square: 0.7510
# Epoch 116/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.5734 - r_square: 0.7749 - val_loss: 14.1243 - val_r_square: 0.7512
# Epoch 117/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.4882 - r_square: 0.7798 - val_loss: 14.0734 - val_r_square: 0.7559
# Epoch 118/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.4721 - r_square: 0.7816 - val_loss: 13.9715 - val_r_square: 0.7609
# Epoch 119/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.3977 - r_square: 0.7869 - val_loss: 14.0034 - val_r_square: 0.7719
# Epoch 120/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.3204 - r_square: 0.7920 - val_loss: 14.1692 - val_r_square: 0.7778
# Epoch 121/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.2875 - r_square: 0.7944 - val_loss: 14.0548 - val_r_square: 0.7722
# Epoch 122/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.2472 - r_square: 0.7987 - val_loss: 14.1600 - val_r_square: 0.7821
# Epoch 123/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.1572 - r_square: 0.8030 - val_loss: 14.0415 - val_r_square: 0.7830
# Epoch 124/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.1367 - r_square: 0.8045 - val_loss: 14.2268 - val_r_square: 0.7783
# Epoch 125/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.0739 - r_square: 0.8083 - val_loss: 14.2028 - val_r_square: 0.7944
# Epoch 126/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 18.0756 - r_square: 0.8093 - val_loss: 14.2757 - val_r_square: 0.7921
# Epoch 127/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.9797 - r_square: 0.8141 - val_loss: 14.3355 - val_r_square: 0.8067
# Epoch 128/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.9262 - r_square: 0.8178 - val_loss: 14.3362 - val_r_square: 0.8004
# Epoch 129/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.8978 - r_square: 0.8195 - val_loss: 14.4313 - val_r_square: 0.8140
# Epoch 130/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.8616 - r_square: 0.8216 - val_loss: 14.4360 - val_r_square: 0.8128
# Epoch 131/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.8333 - r_square: 0.8235 - val_loss: 14.4875 - val_r_square: 0.8051
# Epoch 132/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.7541 - r_square: 0.8274 - val_loss: 14.4662 - val_r_square: 0.8046
# Epoch 133/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.8087 - r_square: 0.8280 - val_loss: 14.4513 - val_r_square: 0.8080
# Epoch 134/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.7220 - r_square: 0.8319 - val_loss: 14.5351 - val_r_square: 0.8136
# Epoch 135/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.7054 - r_square: 0.8333 - val_loss: 14.5890 - val_r_square: 0.8180
# Epoch 136/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.6471 - r_square: 0.8351 - val_loss: 14.7712 - val_r_square: 0.8194
# Epoch 137/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.6358 - r_square: 0.8369 - val_loss: 14.7147 - val_r_square: 0.8209
# Epoch 138/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.5774 - r_square: 0.8399 - val_loss: 14.7679 - val_r_square: 0.8194
# Epoch 139/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.6049 - r_square: 0.8394 - val_loss: 14.7025 - val_r_square: 0.8203
# Epoch 140/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.5430 - r_square: 0.8405 - val_loss: 14.7966 - val_r_square: 0.8255
# Epoch 141/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.5881 - r_square: 0.8402 - val_loss: 14.8335 - val_r_square: 0.8235
# Epoch 142/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.4715 - r_square: 0.8454 - val_loss: 14.9742 - val_r_square: 0.8312
# Epoch 143/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.4613 - r_square: 0.8463 - val_loss: 14.9657 - val_r_square: 0.8336
# Epoch 144/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.4400 - r_square: 0.8487 - val_loss: 14.8628 - val_r_square: 0.8304
# Epoch 145/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.4417 - r_square: 0.8479 - val_loss: 14.9342 - val_r_square: 0.8268
# Epoch 146/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.3679 - r_square: 0.8515 - val_loss: 15.0108 - val_r_square: 0.8314
# Epoch 147/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.3860 - r_square: 0.8515 - val_loss: 14.9985 - val_r_square: 0.8394
# Epoch 148/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.4222 - r_square: 0.8504 - val_loss: 14.9728 - val_r_square: 0.8366
# Epoch 149/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.3700 - r_square: 0.8529 - val_loss: 15.3057 - val_r_square: 0.8342
# Epoch 150/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.2987 - r_square: 0.8559 - val_loss: 15.2454 - val_r_square: 0.8349
# Epoch 151/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.2803 - r_square: 0.8562 - val_loss: 15.2156 - val_r_square: 0.8389
# Epoch 152/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.3423 - r_square: 0.8534 - val_loss: 15.1196 - val_r_square: 0.8407
# Epoch 153/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.2944 - r_square: 0.8568 - val_loss: 15.1451 - val_r_square: 0.8323
# Epoch 154/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.2296 - r_square: 0.8573 - val_loss: 15.2618 - val_r_square: 0.8380
# Epoch 155/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.2674 - r_square: 0.8584 - val_loss: 15.3324 - val_r_square: 0.8415
# Epoch 156/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.1921 - r_square: 0.8611 - val_loss: 15.1057 - val_r_square: 0.8365
# Epoch 157/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.2135 - r_square: 0.8598 - val_loss: 15.2970 - val_r_square: 0.8449
# Epoch 158/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.1973 - r_square: 0.8610 - val_loss: 15.3690 - val_r_square: 0.8467
# Epoch 159/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.1461 - r_square: 0.8630 - val_loss: 15.3695 - val_r_square: 0.8457
# Epoch 160/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.1304 - r_square: 0.8631 - val_loss: 15.1306 - val_r_square: 0.8425
# Epoch 161/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.1349 - r_square: 0.8646 - val_loss: 15.1059 - val_r_square: 0.8510
# Epoch 162/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.1524 - r_square: 0.8636 - val_loss: 15.3196 - val_r_square: 0.8526
# Epoch 163/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.1377 - r_square: 0.8641 - val_loss: 15.3008 - val_r_square: 0.8499
# Epoch 164/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.1312 - r_square: 0.8637 - val_loss: 15.2714 - val_r_square: 0.8469
# Epoch 165/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.0229 - r_square: 0.8676 - val_loss: 15.3594 - val_r_square: 0.8527
# Epoch 166/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.1355 - r_square: 0.8649 - val_loss: 15.1650 - val_r_square: 0.8425
# Epoch 167/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.0466 - r_square: 0.8672 - val_loss: 15.3321 - val_r_square: 0.8444
# Epoch 168/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.0833 - r_square: 0.8673 - val_loss: 15.2874 - val_r_square: 0.8472
# Epoch 169/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.0329 - r_square: 0.8691 - val_loss: 15.3184 - val_r_square: 0.8518
# Epoch 170/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.0327 - r_square: 0.8696 - val_loss: 15.1052 - val_r_square: 0.8474
# Epoch 171/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.0304 - r_square: 0.8692 - val_loss: 15.2278 - val_r_square: 0.8585
# Epoch 172/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.0289 - r_square: 0.8695 - val_loss: 15.1718 - val_r_square: 0.8510
# Epoch 173/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.9676 - r_square: 0.8711 - val_loss: 15.1682 - val_r_square: 0.8504
# Epoch 174/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.9765 - r_square: 0.8710 - val_loss: 15.4019 - val_r_square: 0.8557
# Epoch 175/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.0047 - r_square: 0.8706 - val_loss: 15.3184 - val_r_square: 0.8524
# Epoch 176/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.9492 - r_square: 0.8729 - val_loss: 15.2760 - val_r_square: 0.8590
# Epoch 177/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.9476 - r_square: 0.8723 - val_loss: 15.3268 - val_r_square: 0.8590
# 646/646 [==============================] - 1s 888us/step
# 1398/1398 [==============================] - 1s 933us/step
# Trying different rates:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.333:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.667:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 1.0:   0%|          | 0/3 [00:00<?, ?it/s]
# 2044/2044 [==============================] - 2s 919us/step
# Getting portfolio rois:   0%|          | 0/6851 [00:00<?, ?it/s]
# Creating interactive scatterplot
# Saving interactive scatterplot
# Saved interactive scatterplot
# C:\Users\brarn\AppData\Local\Temp\ipykernel_8072\1656905027.py:362: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Working on model:
# Data: 16Lines-3Years-[Cars, Indu production, Manu $, Narrow $]Features-[sectors]Categorical
# Layers: 2
# Neurons: 32
# Batch size = 2048
# Technique = dropout & batch
#
# Epoch 1/200
# 1398/1398 [==============================] - 6s 3ms/step - loss: 66.5775 - r_square: -0.1501 - val_loss: 43.3278 - val_r_square: -0.1670
# Epoch 2/200
#   45/1398 [..............................] - ETA: 4s - loss: 65.7639 - r_square: -0.1570
# c:\Users\brarn\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 1398/1398 [==============================] - 4s 3ms/step - loss: 66.1923 - r_square: -0.1488 - val_loss: 43.1988 - val_r_square: -0.1673
# Epoch 3/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 65.8237 - r_square: -0.1476 - val_loss: 43.0774 - val_r_square: -0.1675
# Epoch 4/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 65.4692 - r_square: -0.1467 - val_loss: 42.9197 - val_r_square: -0.1670
# Epoch 5/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 65.1333 - r_square: -0.1455 - val_loss: 42.7230 - val_r_square: -0.1657
# Epoch 6/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 64.8121 - r_square: -0.1439 - val_loss: 42.5098 - val_r_square: -0.1642
# Epoch 7/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 64.5020 - r_square: -0.1426 - val_loss: 42.2783 - val_r_square: -0.1628
# Epoch 8/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 64.1924 - r_square: -0.1407 - val_loss: 42.0257 - val_r_square: -0.1603
# Epoch 9/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 63.8836 - r_square: -0.1389 - val_loss: 41.7630 - val_r_square: -0.1580
# Epoch 10/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 63.5751 - r_square: -0.1368 - val_loss: 41.4790 - val_r_square: -0.1552
# Epoch 11/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 63.2702 - r_square: -0.1348 - val_loss: 41.1707 - val_r_square: -0.1519
# Epoch 12/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 62.9525 - r_square: -0.1324 - val_loss: 40.8542 - val_r_square: -0.1484
# Epoch 13/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 62.6312 - r_square: -0.1302 - val_loss: 40.5513 - val_r_square: -0.1450
# Epoch 14/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 62.3009 - r_square: -0.1277 - val_loss: 40.2232 - val_r_square: -0.1415
# Epoch 15/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 61.9646 - r_square: -0.1253 - val_loss: 39.8755 - val_r_square: -0.1379
# Epoch 16/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 61.6218 - r_square: -0.1229 - val_loss: 39.5004 - val_r_square: -0.1340
# Epoch 17/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 61.2691 - r_square: -0.1201 - val_loss: 39.1402 - val_r_square: -0.1302
# Epoch 18/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 60.9104 - r_square: -0.1173 - val_loss: 38.7122 - val_r_square: -0.1260
# Epoch 19/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 60.5336 - r_square: -0.1144 - val_loss: 38.2846 - val_r_square: -0.1218
# Epoch 20/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 60.1458 - r_square: -0.1114 - val_loss: 37.8498 - val_r_square: -0.1172
# Epoch 21/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 59.7468 - r_square: -0.1082 - val_loss: 37.3913 - val_r_square: -0.1121
# Epoch 22/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 59.3385 - r_square: -0.1046 - val_loss: 36.8906 - val_r_square: -0.1065
# Epoch 23/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 58.9167 - r_square: -0.1010 - val_loss: 36.4191 - val_r_square: -0.1013
# Epoch 24/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 58.4868 - r_square: -0.0970 - val_loss: 35.9001 - val_r_square: -0.0949
# Epoch 25/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 58.0466 - r_square: -0.0926 - val_loss: 35.4447 - val_r_square: -0.0881
# Epoch 26/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 57.5922 - r_square: -0.0882 - val_loss: 34.9659 - val_r_square: -0.0820
# Epoch 27/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 57.1309 - r_square: -0.0837 - val_loss: 34.5178 - val_r_square: -0.0750
# Epoch 28/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 56.6478 - r_square: -0.0788 - val_loss: 34.1640 - val_r_square: -0.0695
# Epoch 29/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 56.1546 - r_square: -0.0741 - val_loss: 33.6777 - val_r_square: -0.0628
# Epoch 30/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 55.6540 - r_square: -0.0695 - val_loss: 33.3944 - val_r_square: -0.0581
# Epoch 31/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 55.1345 - r_square: -0.0650 - val_loss: 32.9175 - val_r_square: -0.0523
# Epoch 32/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 54.6152 - r_square: -0.0606 - val_loss: 32.4958 - val_r_square: -0.0466
# Epoch 33/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 54.0849 - r_square: -0.0559 - val_loss: 32.2072 - val_r_square: -0.0417
# Epoch 34/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 53.5363 - r_square: -0.0512 - val_loss: 31.8124 - val_r_square: -0.0360
# Epoch 35/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 52.9849 - r_square: -0.0467 - val_loss: 31.4070 - val_r_square: -0.0312
# Epoch 36/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 52.4178 - r_square: -0.0420 - val_loss: 30.9616 - val_r_square: -0.0256
# Epoch 37/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 51.8459 - r_square: -0.0379 - val_loss: 30.3252 - val_r_square: -0.0198
# Epoch 38/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 51.2716 - r_square: -0.0337 - val_loss: 29.8670 - val_r_square: -0.0150
# Epoch 39/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 50.6958 - r_square: -0.0294 - val_loss: 29.3236 - val_r_square: -0.0095
# Epoch 40/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 50.1071 - r_square: -0.0250 - val_loss: 28.8432 - val_r_square: -0.0043
# Epoch 41/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 49.5383 - r_square: -0.0208 - val_loss: 28.2270 - val_r_square: 0.0013
# Epoch 42/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 48.9544 - r_square: -0.0163 - val_loss: 27.7344 - val_r_square: 0.0067
# Epoch 43/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 48.3730 - r_square: -0.0113 - val_loss: 27.2841 - val_r_square: 0.0118
# Epoch 44/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 47.7969 - r_square: -0.0057 - val_loss: 26.6333 - val_r_square: 0.0184
# Epoch 45/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 47.2115 - r_square: -6.2561e-04 - val_loss: 26.2894 - val_r_square: 0.0238
# Epoch 46/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 46.6440 - r_square: 0.0054 - val_loss: 25.8631 - val_r_square: 0.0296
# Epoch 47/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 46.0845 - r_square: 0.0116 - val_loss: 25.3760 - val_r_square: 0.0368
# Epoch 48/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 45.5177 - r_square: 0.0186 - val_loss: 25.1051 - val_r_square: 0.0436
# Epoch 49/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 44.9349 - r_square: 0.0275 - val_loss: 24.7062 - val_r_square: 0.0539
# Epoch 50/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 44.2567 - r_square: 0.0407 - val_loss: 24.1446 - val_r_square: 0.0625
# Epoch 51/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 43.6394 - r_square: 0.0467 - val_loss: 23.5987 - val_r_square: 0.0677
# Epoch 52/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 43.0564 - r_square: 0.0531 - val_loss: 23.1548 - val_r_square: 0.0744
# Epoch 53/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 42.5171 - r_square: 0.0604 - val_loss: 22.8048 - val_r_square: 0.0811
# Epoch 54/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 41.9765 - r_square: 0.0682 - val_loss: 22.4515 - val_r_square: 0.0887
# Epoch 55/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 41.4447 - r_square: 0.0771 - val_loss: 22.0187 - val_r_square: 0.0967
# Epoch 56/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 40.9177 - r_square: 0.0870 - val_loss: 21.9282 - val_r_square: 0.1054
# Epoch 57/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 40.4039 - r_square: 0.0966 - val_loss: 21.6416 - val_r_square: 0.1141
# Epoch 58/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 39.9058 - r_square: 0.1068 - val_loss: 21.1954 - val_r_square: 0.1228
# Epoch 59/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 39.4174 - r_square: 0.1167 - val_loss: 20.8487 - val_r_square: 0.1337
# Epoch 60/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 38.9332 - r_square: 0.1291 - val_loss: 20.5763 - val_r_square: 0.1445
# Epoch 61/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 38.4530 - r_square: 0.1409 - val_loss: 20.4414 - val_r_square: 0.1559
# Epoch 62/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 37.9902 - r_square: 0.1531 - val_loss: 20.1874 - val_r_square: 0.1674
# Epoch 63/200
# ...
# 1398/1398 [==============================] - 3s 2ms/step - loss: 21.0959 - r_square: 0.7780 - val_loss: 11.9793 - val_r_square: 0.8438
# Epoch 3/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 17.0712 - r_square: 0.8908 - val_loss: 11.5333 - val_r_square: 0.8790
# Epoch 4/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.7020 - r_square: 0.9066 - val_loss: 11.3899 - val_r_square: 0.8858
# Epoch 5/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.6241 - r_square: 0.9098 - val_loss: 11.3535 - val_r_square: 0.8872
# Epoch 6/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.5929 - r_square: 0.9104 - val_loss: 11.3299 - val_r_square: 0.8879
# Epoch 7/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.5728 - r_square: 0.9107 - val_loss: 11.3194 - val_r_square: 0.8879
# Epoch 8/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.5571 - r_square: 0.9108 - val_loss: 11.3094 - val_r_square: 0.8882
# Epoch 9/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.5432 - r_square: 0.9110 - val_loss: 11.3064 - val_r_square: 0.8883
# Epoch 10/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.5297 - r_square: 0.9111 - val_loss: 11.3014 - val_r_square: 0.8884
# Epoch 11/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.5170 - r_square: 0.9112 - val_loss: 11.2970 - val_r_square: 0.8883
# Epoch 12/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.5047 - r_square: 0.9113 - val_loss: 11.3015 - val_r_square: 0.8883
# Epoch 13/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.4926 - r_square: 0.9114 - val_loss: 11.2970 - val_r_square: 0.8884
# Epoch 14/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.4810 - r_square: 0.9115 - val_loss: 11.2977 - val_r_square: 0.8884
# Epoch 15/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.4697 - r_square: 0.9117 - val_loss: 11.2964 - val_r_square: 0.8884
# Epoch 16/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.4586 - r_square: 0.9117 - val_loss: 11.2962 - val_r_square: 0.8885
# Epoch 17/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.4471 - r_square: 0.9119 - val_loss: 11.2957 - val_r_square: 0.8886
# Epoch 18/200
# 1398/1398 [==============================] - 3s 2ms/step - loss: 16.4366 - r_square: 0.9121 - val_loss: 11.3074 - val_r_square: 0.8884
# 646/646 [==============================] - 1s 1ms/step
# 1398/1398 [==============================] - 1s 1ms/step
# Trying different rates:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.333:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.667:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 1.0:   0%|          | 0/3 [00:00<?, ?it/s]
# 2044/2044 [==============================] - 2s 999us/step
# Getting portfolio rois:   0%|          | 0/6851 [00:00<?, ?it/s]
# Creating interactive scatterplot
# Saving interactive scatterplot
# Saved interactive scatterplot
# C:\Users\brarn\AppData\Local\Temp\ipykernel_8072\1656905027.py:362: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# Working on model:
# Data: 16Lines-3Years-[Cars, Indu production, Manu $, Narrow $]Features-[sectors]Categorical
# Layers: 2
# Neurons: 64
# Batch size = 2048
# Technique = dropout layers
#
# Epoch 1/200
# 1398/1398 [==============================] - 6s 4ms/step - loss: 64.4079 - r_square: -0.0239 - val_loss: 25.0450 - val_r_square: 0.2833
# Epoch 2/200
#   52/1398 [>.............................] - ETA: 4s - loss: 53.4347 - r_square: 0.2419
# c:\Users\brarn\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning:
#
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# 1398/1398 [==============================] - 5s 3ms/step - loss: 45.9216 - r_square: 0.4442 - val_loss: 18.0283 - val_r_square: 0.6700
# Epoch 3/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 33.5645 - r_square: 0.7162 - val_loss: 15.5995 - val_r_square: 0.8379
# Epoch 4/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 28.3709 - r_square: 0.7820 - val_loss: 15.4042 - val_r_square: 0.8695
# Epoch 5/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 26.2128 - r_square: 0.7968 - val_loss: 15.1085 - val_r_square: 0.8747
# Epoch 6/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 24.9489 - r_square: 0.8037 - val_loss: 14.6856 - val_r_square: 0.8768
# Epoch 7/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 24.0923 - r_square: 0.8106 - val_loss: 14.2616 - val_r_square: 0.8775
# Epoch 8/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 23.4582 - r_square: 0.8158 - val_loss: 13.8458 - val_r_square: 0.8784
# Epoch 9/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 23.0210 - r_square: 0.8213 - val_loss: 13.4187 - val_r_square: 0.8798
# Epoch 10/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 22.6511 - r_square: 0.8261 - val_loss: 13.2126 - val_r_square: 0.8801
# Epoch 11/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 22.3935 - r_square: 0.8297 - val_loss: 13.0462 - val_r_square: 0.8798
# Epoch 12/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 22.1777 - r_square: 0.8342 - val_loss: 12.8366 - val_r_square: 0.8798
# Epoch 13/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 22.0171 - r_square: 0.8369 - val_loss: 12.7103 - val_r_square: 0.8794
# Epoch 14/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.8489 - r_square: 0.8367 - val_loss: 12.5647 - val_r_square: 0.8798
# Epoch 15/200
# 1398/1398 [==============================] - 4s 3ms/step - loss: 21.7071 - r_square: 0.8401 - val_loss: 12.5401 - val_r_square: 0.8793
# Epoch 16/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.6486 - r_square: 0.8401 - val_loss: 12.5028 - val_r_square: 0.8785
# Epoch 17/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.5477 - r_square: 0.8432 - val_loss: 12.4823 - val_r_square: 0.8778
# Epoch 18/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.4797 - r_square: 0.8416 - val_loss: 12.4460 - val_r_square: 0.8781
# Epoch 19/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.3611 - r_square: 0.8465 - val_loss: 12.4171 - val_r_square: 0.8776
# Epoch 20/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.2914 - r_square: 0.8467 - val_loss: 12.4327 - val_r_square: 0.8777
# Epoch 21/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.2653 - r_square: 0.8447 - val_loss: 12.4189 - val_r_square: 0.8771
# Epoch 22/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.1901 - r_square: 0.8481 - val_loss: 12.4591 - val_r_square: 0.8764
# Epoch 23/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.1243 - r_square: 0.8489 - val_loss: 12.4355 - val_r_square: 0.8762
# Epoch 24/200
# 1398/1398 [==============================] - 5s 3ms/step - loss: 21.0881 - r_square: 0.8488 - val_loss: 12.4013 - val_r_square: 0.8760
# 646/646 [==============================] - 1s 952us/step
# 1398/1398 [==============================] - 2s 1ms/step
# Trying different rates:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.333:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 0.667:   0%|          | 0/3 [00:00<?, ?it/s]
# Getting rois for rate: 1.0:   0%|          | 0/3 [00:00<?, ?it/s]
# 2044/2044 [==============================] - 2s 1ms/step
# Getting portfolio rois:   0%|          | 0/6851 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 277
#     275 rois = np.zeros((len(port_index),2))
#     276 extra_data = []
# --> 277 for i, date in port_index_tqdm:
#     278     if date in test_dates:
#     279         dataset_string = "test"
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\tqdm\notebook.py:254, in tqdm_notebook.__iter__(self)
#     252 try:
#     253     it = super(tqdm_notebook, self).__iter__()
# --> 254     for obj in it:
#     255         # return super(tqdm...) will not catch exception
#     256         yield obj
#     257 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\tqdm\std.py:1188, in tqdm.__iter__(self)
#    1186 dt = cur_t - last_print_t
#    1187 if dt >= mininterval and cur_t >= min_start_t:
# -> 1188     self.update(n - last_print_n)
#    1189     last_print_n = self.last_print_n
#    1190     last_print_t = self.last_print_t
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\tqdm\notebook.py:266, in tqdm_notebook.update(self, n)
#     264 def update(self, n=1):
#     265     try:
# --> 266         return super(tqdm_notebook, self).update(n=n)
#     267     # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#     268     except:  # NOQA
#     269         # cannot catch KeyboardInterrupt when using manual tqdm
#     270         # as the interrupt will most likely happen on another statement
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\tqdm\std.py:1239, in tqdm.update(self, n)
#    1237     self._ema_dn(dn)
#    1238     self._ema_dt(dt)
# -> 1239 self.refresh(lock_args=self.lock_args)
#    1240 if self.dynamic_miniters:
#    1241     # If no `miniters` was specified, adjust automatically to the
#    1242     # maximum iteration rate seen so far between two prints.
#    1243     # e.g.: After running `tqdm.update(5)`, subsequent
#    1244     # calls to `tqdm.update()` will only cause an update after
#    1245     # at least 5 more iterations.
#    1246     if self.maxinterval and dt >= self.maxinterval:
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\tqdm\std.py:1344, in tqdm.refresh(self, nolock, lock_args)
#    1342     else:
#    1343         self._lock.acquire()
# -> 1344 self.display()
#    1345 if not nolock:
#    1346     self._lock.release()
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\tqdm\notebook.py:162, in tqdm_notebook.display(self, msg, pos, close, bar_style, check_delay)
#     159     msg = self.format_meter(**d)
#     161 ltext, pbar, rtext = self.container.children
# --> 162 pbar.value = self.n
#     164 if msg:
#     165     # html escape special characters (like '&')
#     166     if '<bar/>' in msg:
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\traitlets\traitlets.py:729, in TraitType.__set__(self, obj, value)
#     727     raise TraitError('The "%s" trait is read-only.' % self.name)
#     728 else:
# --> 729     self.set(obj, value)
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\traitlets\traitlets.py:718, in TraitType.set(self, obj, value)
#     714     silent = False
#     715 if silent is not True:
#     716     # we explicitly compare silent to True just in case the equality
#     717     # comparison above returns something other than True/False
# --> 718     obj._notify_trait(self.name, old_value, new_value)
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\traitlets\traitlets.py:1501, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1500 def _notify_trait(self, name, old_value, new_value):
# -> 1501     self.notify_change(
#    1502         Bunch(
#    1503             name=name,
#    1504             old=old_value,
#    1505             new=new_value,
#    1506             owner=self,
#    1507             type="change",
#    1508         )
#    1509     )
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:693, in Widget.notify_change(self, change)
#     689 if self.comm is not None and self.comm.kernel is not None:
#     690     # Make sure this isn't information that the front-end just sent us.
#     691     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     692         # Send new state to front-end
# --> 693         self.send_state(key=name)
#     694 super().notify_change(change)
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:579, in Widget.send_state(self, key)
#     577 state, buffer_paths, buffers = _remove_buffers(state)
#     578 msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 579 self._send(msg, buffers=buffers)
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\ipywidgets\widgets\widget.py:818, in Widget._send(self, msg, buffers)
#     816 """Sends a message to the model in the front-end."""
#     817 if self.comm is not None and self.comm.kernel is not None:
# --> 818     self.comm.send(data=msg, buffers=buffers)
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\comm\base_comm.py:113, in BaseComm.send(self, data, metadata, buffers)
#     111 def send(self, data=None, metadata=None, buffers=None):
#     112     """Send a message to the frontend-side version of this comm"""
# --> 113     self.publish_msg(
#     114         "comm_msg",
#     115         data=data,
#     116         metadata=metadata,
#     117         buffers=buffers,
#     118     )
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\ipykernel\comm\comm.py:33, in BaseComm.publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      30 if self.kernel is None:
#      31     self.kernel = Kernel.instance()
# ---> 33 self.kernel.session.send(
#      34     self.kernel.iopub_socket,
#      35     msg_type,
#      36     content,
#      37     metadata=json_clean(metadata),
#      38     parent=self.kernel.get_parent("shell"),
#      39     ident=self.topic,
#      40     buffers=buffers,
#      41 )
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\jupyter_client\session.py:861, in Session.send(self, stream, msg_or_type, content, parent, ident, buffers, track, header, metadata)
#     858 elif stream:
#     859     # use dummy tracker, which will be done immediately
#     860     tracker = DONE
# --> 861     stream.send_multipart(to_send, copy=copy)
#     863 if self.debug:
#     864     pprint.pprint(msg)
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\ipykernel\iostream.py:286, in BackgroundSocket.send_multipart(self, *args, **kwargs)
#     284 """Schedule send in IO thread"""
#     285 assert self.io_thread is not None
# --> 286 return self.io_thread.send_multipart(*args, **kwargs)
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\ipykernel\iostream.py:219, in IOPubThread.send_multipart(self, *args, **kwargs)
#     214 def send_multipart(self, *args, **kwargs):
#     215     """send_multipart schedules actual zmq send in my thread.
#     216
#     217     If my thread isn't running (e.g. forked process), send immediately.
#     218     """
# --> 219     self.schedule(lambda: self._really_send(*args, **kwargs))
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\ipykernel\iostream.py:210, in IOPubThread.schedule(self, f)
#     208     self._events.append(f)
#     209     # wake event thread (message content is ignored)
# --> 210     self._event_pipe.send(b"")
#     211 else:
#     212     f()
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\zmq\sugar\socket.py:696, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     689         data = zmq.Frame(
#     690             data,
#     691             track=track,
#     692             copy=copy or None,
#     693             copy_threshold=self.copy_threshold,
#     694         )
#     695     data.group = group
# --> 696 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:742, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:789, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:250, in zmq.backend.cython.socket._send_copy()
#
# File c:\Users\brarn\anaconda3\Lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
